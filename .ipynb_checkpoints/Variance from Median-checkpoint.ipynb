# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

dataset_id = "PXD027742" # Indicate Dataset Here

filepath = dataset_id + "/psm.TSV"

identifier = "434x Carrier"

psm_df = pd.read_csv(filepath, delimiter = "\t")


psm_df = psm_df.loc[psm_df["PeptideProphet Probability"] > 0.95]

# psm_df = psm_df.drop(["126", "127N", "127C"], axis=1)

psm_df = pd.melt(psm_df, id_vars=["Spectrum File"], value_vars=["126","127N","127C","128C","128N","129C","129N","130C",
                                                                "130N","131C","131N","132C","132N","133C","133N","134N"])

df_No_1 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_No126_100pg_AGC300_1.pep.xml"]
df_No_2 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_No126_100pg_AGC300_2.pep.xml"]
df_14_1 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H14_100pg_AGC300_1.pep.xml"]
df_14_2 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H14_100pg_AGC300_2.pep.xml"]
df_42_1 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H42_100pg_AGC300_1.pep.xml"]
df_42_2 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H42_100pg_AGC300_2.pep.xml"]
df_98_1 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H98_100pg_AGC300_1.pep.xml"]
df_98_2 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H98_100pg_AGC300_2.pep.xml"]
df_210_1 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H210_100pg_AGC300_1.pep.xml"]
df_210_2 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H210_100pg_AGC300_2.pep.xml"]
df_434_1 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H434_100pg_AGC300_1.pep.xml"]
df_434_2 = psm_df.loc[psm_df["Spectrum File"] == "D:\\Users\\PCL_user\\Mass_Spec\\data\\TMT_sc_data\\Datasets\\PXD027742\\output\\interact-20200820_EXPL8_EVO1_ZY_SA_44min_TMT_H434_100pg_AGC300_2.pep.xml"]

# median_No_1 = df_No_1['value'].median()
# median_No_2 = df_No_2['value'].median()
# median_14_1 = df_14_1['value'].median()
# median_14_2 = df_14_2['value'].median()
# median_42_1 = df_42_1['value'].median()
# median_42_2 = df_42_2['value'].median()
# median_98_1 = df_98_1['value'].median()
# median_98_2 = df_98_2['value'].median()
# median_210_1 = df_210_1['value'].median()
# median_210_2 = df_210_2['value'].median()
# median_434_1 = df_434_1['value'].median()
# median_434_2 = df_434_2['value'].median()

# all_medians = [median_No_1, median_No_2, median_14_1, median_14_2, median_42_1, median_42_2, median_98_1, median_98_2, median_210_1, median_210_2, median_434_1, median_434_2]

# median_of_medians = st.median(all_medians)
datasets = ["df_No_1", "df_No_2", "df_14_1", "df_14_2", "df_42_1", "df_42_2", "df_98_1", "df_98_2", "df_210_1", "df_210_2", "df_434_1", "df_434_2"]
channels = ["126","127C","127N","128C","128N","129C","129N","130C","130N","131C","131N","132C","132N","133C","133N","134N"]
medians_df = pd.DataFrame(index=datasets, columns=channels)


for dataset in datasets:
    for channel in channels:
        curr_df =  vars()[dataset]
        curr_df = curr_df.loc[curr_df["variable"] == channel]
        medians_df.at[dataset, channel] = curr_df['value'].median()
        
medians_df['Median'] = medians_df[channels].median(axis=1)

medians_df

# psm_df["value"] = psm_df["value"].apply(np.log10)
# psm_df["value"] = np.log10(psm_df["value"].replace(0, np.nan))
# Out:
#                     126          127C         127N         128C         128N  \
# df_No_1       1389.6747           0.0    24331.498   27328.3105   28835.3223
# df_No_2      1077.36255           0.0  22918.38965   26013.9082  27594.44435
# df_14_1     202222.4219    12302.4189   18971.3301   21552.4531   21699.3145
# df_14_2    204534.26565   12203.36425  18883.74805   21265.8193   21732.0137
# df_42_1    515769.67185    31415.9834   15822.4307   17137.0059  16841.17675
# df_42_2    523465.23435   32707.75585   16216.0918   17717.4209  17348.86035
# df_98_1   1015936.84375   62944.67575  15892.90865  16429.43555  15089.65775
# df_98_2    886923.59375    55768.3672   14128.0161  14506.01465  13513.05955
# df_210_1     2217351.75   137827.5625   18778.0508   17402.2773   14537.3154
# df_210_2     2283713.75   144359.2656   19404.2109   18137.3711   14681.4883
# df_434_1      4518172.5  274335.40625   25803.0957   21511.5781   14051.7148
# ...

# %%
variance_df = pd.DataFrame(index=datasets, columns=channels)

for dataset in datasets:
    for channel in channels:
        variance_df.at[dataset, channel] = medians_df.at[dataset, channel] / medians_df.at[dataset, "Median"]
        
variance_df
# Out:
#                  126       127C      127N      128C      128N      129C  \
# df_No_1     0.052524        0.0  0.919637  1.032905  1.089865  1.024697
# df_No_2     0.042205        0.0  0.897815   1.01908  1.080997  1.026031
# df_14_1    10.138823   0.616806  0.951165  1.080575  1.087938   1.09273
# df_14_2    10.252865   0.611729  0.946602   1.06601  1.089379  1.070628
# df_42_1     31.99733   1.948985  0.981592  1.063146  1.044793   1.03442
# df_42_2    31.601552   1.974564  0.978964  1.069599  1.047349  1.029073
# df_98_1    69.026543   4.276696  1.079824  1.116277  1.025248  0.997298
# df_98_2    68.761812   4.323635  1.095323  1.124629  1.047647  1.006414
# df_210_1   164.19024  10.205841  1.390475  1.288602  1.076458  1.035514
# df_210_2  163.708833  10.348445  1.390998  1.300184  1.052448  1.012407
# df_434_1  345.524171  20.979614  1.973274  1.645083  1.074595  1.005729
# df_434_2   343.43662  21.084263   1.94037  1.630329   1.07048   1.00087
#
# ...

# %%
to_graph_df = pd.melt(variance_df, value_vars=["128C","128N","129C","129N","130C","130N","131C","131N","132C","132N","133C","133N","134N"], ignore_index=False)
to_graph_df["Dataset"] = to_graph_df.index
to_graph_df
# Out:
#          variable     value   Dataset
# df_No_1      128C  1.032905   df_No_1
# df_No_2      128C   1.01908   df_No_2
# df_14_1      128C  1.080575   df_14_1
# df_14_2      128C   1.06601   df_14_2
# df_42_1      128C  1.063146   df_42_1
# ...           ...       ...       ...
# df_98_2      134N  0.954349   df_98_2
# df_210_1     134N  0.963999  df_210_1
# df_210_2     134N  0.958594  df_210_2
# df_434_1     134N   0.94555  df_434_1
# df_434_2     134N   0.93776  df_434_2
#
# [156 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6.2025)) # Original: (16, 8.27)
# true_colors = ["#E1DCEE", "#9DE4AA", "#CADBF1", "#E8CBD9"]
# sns.set_palette(sns.color_palette(colors))



color_match = {"df_No_1": "#000000", "df_No_2": "#000000", "df_14_1": "#56B4E9", "df_14_2": "#56B4E9",
               "df_42_1": "#009E73", "df_42_2": "#009E73", "df_98_1": "#E69F00", "df_98_2": "#E69F00",
               "df_210_1": "#F0E442", "df_210_2": "#F0E442", "df_434_1": "#CC79A7", "df_434_2": "#CC79A7"}

sns.set(font_scale=1.05)
sns.set_style("whitegrid")

# boxplot = sns.boxplot(data=psm_df, x="variable", y="value", palette = color_match,
#                       order=["126","127N","127C","128N","128C","129N","129C","130N",
#                              "130C","131N","131C","132N","132C","133N","133C","134N"])


boxplot = sns.stripplot(data=to_graph_df, x="variable", y="value", jitter=True, hue="Dataset", palette = color_match, 
                     order=["128N","128C","129N","129C","130N",
                            "130C","131N","131C","132N","132C","133N","133C","134N"])

plt.axhline(y=1)

boxplot.set(xlabel="Sample Label", ylabel="") # Change y label

# plt.legend(labels=['legendEntry1', 'legendEntry2', 'legendEntry3', 'legendEntry4', 'legendEntry5', '6', '7', '8'])
# sns.move_legend(boxplot, "center left")
plt.show()
# plt.savefig('proteinabundance.png', dpi=400)
